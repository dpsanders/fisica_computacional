# %% [markdown]
# # Dudas

# %% [markdown]
# - `PyPlot`:

# %%
Pkg.add("PyPlot")
# Out:
# INFO: Installing Dates v0.3.2
# INFO: Installing LaTeXStrings v0.1.4
# INFO: Installing PyCall v0.8.2
# INFO: Installing PyPlot v1.5.3
# INFO: Package database updated
# INFO: METADATA might be out-of-date — you may not have the latest version of PyPlot
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
plot(rand(10), rand(10))
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11ffa5310>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x120066290>

# %% [markdown]
# (Necesitas tener instalado la librería `matplotlib` de Python: viene automáticamente con Anaconda, o pones
#
# `pip install matplotlib`
#
# `pip` es un gestor de paquetes de Python:
#
# `sudo apt-get install pip`
# )

# %% [markdown]
# # Elementos de un vector

# %%
v = [3, 4, 5]
# Out:
# 3-element Array{Int64,1}:
#  3
#  4
#  5

# %%
v[2]
# Out:
# 4

# %%
w = [6, 7, 8]
# Out:
# 3-element Array{Int64,1}:
#  6
#  7
#  8

# %%
z[1] = v[1]*w[1]
# Out:
# z not defined
# while loading In[7], in expression starting on line 1

# %%
z = zeros(3)
# Out:
# 3-element Array{Float64,1}:
#  0.0
#  0.0
#  0.0

# %%
z[1]
# Out:
# 0.0

# %%
z[1] = 105
# Out:
# 105

# %%
z
# Out:
# 3-element Array{Float64,1}:
#  105.0
#    0.0
#    0.0

# %%
z = similar(v)
# Out:
# 3-element Array{Int64,1}:
#       4550363304
#  140515114966240
#  140515114817664

# %%
z = zeros(Int, 3)
# Out:
# 3-element Array{Int64,1}:
#  0
#  0
#  0

# %%
z = zeros(v)
# Out:
# 3-element Array{Int64,1}:
#  0
#  0
#  0

# %%
methods(zeros)
# Out:
# # 3 methods for generic function "zeros":
# zeros(T::Type{T<:Top},dims...) at array.jl:169
# zeros{T}(A::AbstractArray{T,N}) at array.jl:171
# zeros(dims...) at array.jl:170

# %%
v
# Out:
# 3-element Array{Int64,1}:
#  3
#  4
#  5

# %%
ndims(v)
# Out:
# 1

# %%
lenght(v)
# Out:
# lenght not defined
# while loading In[19], in expression starting on line 1

# %%
length(v)  # len<TAB>
# Out:
# 3

# %% [markdown]
# ## Producto punto

# %%
v = [3, 4, 5]
w = [7, 8, 9]
# Out:
# 3-element Array{Int64,1}:
#  7
#  8
#  9

# %%
⋅
# Out:
# dot (generic function with 7 methods)

# %%
dot(v, w)
# Out:
# 98

# %%
⋅(v, w)
# Out:
# 98

# %%
v ⋅ w
# Out:
# 98

# %%
☃ = dot
# Out:
# dot (generic function with 7 methods)

# %%
☃(v, w)
# Out:
# 98

# %%
v ☃ w
# Out:
# syntax: extra token "☃" after end of expression
# while loading In[29], in expression starting on line 1

# %%
using Docile

# %%
@doc fft
# Out:
# @doc not defined
# while loading In[30], in expression starting on line 1
